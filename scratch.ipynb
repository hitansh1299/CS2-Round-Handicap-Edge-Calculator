# %%
from demoparser2 import DemoParser

# %% [markdown]
# Team 1 Score
# Team 2 Score
# All Players 1...5 Kills|Deaths|Assists|Rating 2.0|Cash at round start
# Current map
# First half or second half

# %%
parser = DemoParser("demos\\iem-katowice-2025-vitality-vs-3dmax-bo3-KNzbDELEQ75v8nvhNNs8tI\\vitality-vs-3dmax-m1-inferno.dem")

# %%
wanted_ticks = parser.parse_event("round_freeze_end")["tick"].tolist()
df = parser.parse_ticks(["current_equip_value", 
                         "total_rounds_played",
                         "kills_total",
                         "deaths_total",
                         "assists_total",
                         "damage_total",
                         "team_rounds_total",
                         "team_clan_name",
                         "balance"
                         ], ticks=wanted_ticks)
df.to_csv('gamedata.csv', index='tick')
df
# Out:
#      total_rounds_played  balance  kills_total  deaths_total  assists_total  \
# 0                      0      150            0             0              0
# 1                      0      150            0             0              0
# 2                      0      150            0             0              0
# 3                      0      150            0             0              0
# 4                      0      150            0             0              0
# ..                   ...      ...          ...           ...            ...
# 345                   34     4800           19            26              6
# 346                   34     4600           22            24              7
# 347                   34     6300           22            22              6
# 348                   34     4400           21            20              4
# 349                   34     8350           30            22              7
#
# ...

# %%
event_df = parser.parse_event("player_death", player=["X", "Y"], other=["total_rounds_played"])
event_df
# Out:
#      assistedflash   assister_X   assister_Y assister_name   assister_steamid  \
# 0            False  2128.291992  -149.018677      Ex3rcice  76561198168198200
# 1            False          NaN          NaN          None               None
# 2            False  1964.710449    88.976852         Lucky  76561198031890115
# 3            False          NaN          NaN          None               None
# 4            False          NaN          NaN          None               None
# ..             ...          ...          ...           ...                ...
# 230          False   429.446411  1863.793701         Djoko  76561198047876970
# 231          False          NaN          NaN          None               None
# 232          False   343.297821  1933.503784         ZywOo  76561198113666193
# 233          False   350.208984  1973.981934         mezii  76561197973140692
# 234          False          NaN          NaN          None               None
#
# ...

# %% [markdown]
# Convert the extracted data into a more usable version (wider), one for each round.

# %%
import pandas as pd
df = pd.read_csv('gamedata.csv')

# %%
[f"player_{i}" for i in range(1,11)]
# Out:
# ['player_1',
#  'player_2',
#  'player_3',
#  'player_4',
#  'player_5',
#  'player_6',
#  'player_7',
#  'player_8',
#  'player_9',
#  'player_10']

# %%
df
# Out:
#        tick  total_rounds_played  balance  kills_total  deaths_total  \
# 0      1263                    0      150            0             0
# 1      1263                    0      150            0             0
# 2      1263                    0      150            0             0
# 3      1263                    0      150            0             0
# 4      1263                    0      150            0             0
# ..      ...                  ...      ...          ...           ...
# 345  286708                   34     4800           19            26
# 346  286708                   34     4600           22            24
# 347  286708                   34     6300           22            22
# 348  286708                   34     4400           21            20
# 349  286708                   34     8350           30            22
#
#      assists_total  damage_total  current_equip_value  team_rounds_total  \
# ...

# %%
list(df['name'].unique())
# Out:
# ['Lucky',
#  'Graviti',
#  'mezii',
#  'ZywOo',
#  'Djoko',
#  'apEX',
#  'flameZ',
#  'Maka',
#  'ropz',
#  'Ex3rcice']

# %%
df = pd.read_csv('gamedata.csv')
# df = df.drop(columns=['steamid'])
team_fields = ['']
suffix_list = [f"player_{i}" for i in range(1,11)]
df['player_name'] = df['name'].replace(dict(zip(list(df['name'].unique()),suffix_list)))
df = df.pivot(index=['tick','total_rounds_played',''], columns=['player_name'])
df
# Out:
#                             balance                                       \
# player_name                player_1 player_10 player_2 player_3 player_4
# tick   total_rounds_played
# 1263   0                        150       100      150      150      150
# 8696   1                          0         0      200      150      100
# 18447  2                        250      1150      350     1800     1800
# 26997  3                       2500      1300     3600        0       50
# 35957  4                          0       400      100     2150     1000
# 43304  5                       2300      2050     2100     2250     1100
# 55739  6                        400       250      200     5050     3000
# 65218  7                        500      1850     1750      650     5900
# 73685  8                       3100      4550     3800     1650        0
# 81044  9                       3000      6750     4600     1950     2000
# ...

# %%
df = pd.read_csv('gamedata.csv')
# df = df.drop(columns=['steamid'])
suffix_list = [f"player_{i}" for i in range(1,11)]
df['player_name'] = df['name'].replace(dict(zip(list(df['name'].unique()),suffix_list)))
# df = df[['name','balance','kills_total','team_clan_name']]
df = df.pivot(index=['tick','total_rounds_played'], columns=['player_name'])
df.columns = ['_'.join(col) for col in df.columns.values]
df = df.to_csv('ithinkigotit.csv')
df

# %% [markdown]
# Create HLTV pipeline

# %%
fetch("https://www.hltv.org/events/8229/iem-katowice-2025-play-in", {
  "headers": {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "accept-language": "en-US,en;q=0.9",
    "priority": "u=0, i",
    "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Microsoft Edge\";v=\"132\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "document",
    "sec-fetch-mode": "navigate",
    "sec-fetch-site": "same-origin",
    "sec-fetch-user": "?1",
    "upgrade-insecure-requests": "1"
  },
  "referrer": "https://www.hltv.org/events/archive",
  "referrerPolicy": "strict-origin-when-cross-origin",
  "body": null,
  "method": "GET",
  "mode": "cors",
  "credentials": "include"
});

# %%
curl 'https://www.hltv.org/events/archive' \
  -H 'accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7' \
  -H 'accept-language: en-US,en;q=0.9,en-IN;q=0.8' \
  -H 'cache-control: max-age=0' \
  -H 'cookie: FCNEC=%5B%5B%22AKsRol9RoeouGf-4-i8DVsuW-rT-zfEEEsffHJ1uGz2FF11_NN8uLu1m7IAocbXIXqxHHbLhgZfphUstMSjPWtr4o9Yz1htBXHagXmUbRr2daCROXg446NMmpPddLXRl8Zh_R2-_Jun6SRg9CfivgHDQ5UfOXPrSCA%3D%3D%22%5D%5D; MatchFilter={%22active%22:false%2C%22live%22:false%2C%22stars%22:1%2C%22lan%22:false%2C%22teams%22:[]}; CookieConsent={stamp:%274ZBjneINr7Sigs9KG1YoCDiBuKvkWpfJYJ8r794o4CWuPnQQIsVQfg==%27%2Cnecessary:true%2Cpreferences:true%2Cstatistics:true%2Cmarketing:true%2Cmethod:%27explicit%27%2Cver:1%2Cutc:1726679551262%2Cregion:%27us-18%27}; _fbp=fb.1.1727793354205.867162684962470655; _ia_loc_c=US; _ia_loc_r=IN; _au_1d=AU1D-0100-001727793355-6AYL6JB4-PAAK; _lc2_
.89.1.1738629011.0.0.0; _sharedid_cst=kSylLAssaw%3D%3D; cto_bundle=pfevnF82cU1RZFYydUslMkI5MVpvSHJubEgxenc4Zm5pYzlmMnR6JTJGaUFlayUyQmR5JTJGYk1yMWJOUkNMOWlobllodGpRNnAwZ2NpZUREMHlIRzR2aWQ0ME5LcG5HcTdNS0lwZ0ZUR3F4T0NWWUhEUHZjSTNwSWZpRWoyWTVUa3lJbDNsZ2l1MFRH; cto_bundle=pfevnF82cU1RZFYydUslMkI5MVpvSHJubEgxenc4Zm5pYzlmMnR6JTJGaUFlayUyQmR5JTJGYk1yMWJOUkNMOWlobllodGpRNnAwZ2NpZUREMHlIRzR2aWQ0ME5LcG5HcTdNS0lwZ0ZUR3F4T0NWWUhEUHZjSTNwSWZpRWoyWTVUa3lJbDNsZ2l1MFRH; cto_bidid=owAjHF8yaHFZQyUyQjZMZnVDUXY2NVRtY0ltZEdRdnYyQ1VGTXhIWTlUZ3JCOHlCQ1hUeiUyQlMyRlBxY25pOXdQUU1HJTJGUTRISGpSQTRXWXZjYjFXV1p4UHd3R1pnZFY0YjN5QWsyTWRmeHExakZTZlJPTSUzRA; cto_bidid=owAjHF8yaHFZQyUyQjZMZnVDUXY2NVRtY0ltZEdRdnYyQ1VGTXhIWTlUZ3JCOHlCQ1hUeiUyQlMyRlBxY25pOXdQUU1HJTJGUTRISGpSQTRXWXZjYjFXV1p4UHd3R1pnZFY0YjN5QWsyTWRmeHExakZTZlJPTSUzRA; cto_dna_bundle=n5pcpl80M0RITmhlJTJCZkMwOUJGQlhaMUN2c3pXU3pnJTJCT2swQUhtQ0twWWp1ekVtWjB3Q1BXWGJDVzV4RzUzbUYxZSUyQlMlMkY' \
  -H 'priority: u=0, i' \
  -H 'referer: https://www.hltv.org/events' \
  -H 'sec-ch-ua: "Not A(Brand";v="8", "Chromium";v="132", "Microsoft Edge";v="132"' \
  -H 'sec-ch-ua-arch: "x86"' \
  -H 'sec-ch-ua-bitness: "64"' \
  -H 'sec-ch-ua-full-version: "132.0.2957.127"' \
  -H 'sec-ch-ua-full-version-list: "Not A(Brand";v="8.0.0.0", "Chromium";v="132.0.6834.111", "Microsoft Edge";v="132.0.2957.127"' \
  -H 'sec-ch-ua-mobile: ?0' \
  -H 'sec-ch-ua-model: ""' \
  -H 'sec-ch-ua-platform: "Windows"' \
  -H 'sec-ch-ua-platform-version: "15.0.0"' \
  -H 'sec-fetch-dest: document' \
  -H 'sec-fetch-mode: navigate' \
  -H 'sec-fetch-site: same-origin' \
  -H 'sec-fetch-user: ?1' \
  -H 'upgrade-insecure-requests: 1' \
  -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36 Edg/132.0.0.0'

# %%
# Out:
# <Response [200]>
# /matches/2378905/g2-vs-faze-iem-katowice-2025
# /matches/2378906/eternal-fire-vs-3dmax-iem-katowice-2025
# /matches/2378903/natus-vincere-vs-spirit-iem-katowice-2025
# /matches/2378901/furia-vs-astralis-iem-katowice-2025
# /matches/2378902/mouz-vs-liquid-iem-katowice-2025
# /matches/2378904/gamerlegion-vs-the-mongolz-iem-katowice-2025
# /matches/2378899/vitality-vs-faze-iem-katowice-2025
